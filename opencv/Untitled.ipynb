# %%
import numpy as np
import cv2 as cv

# %%
img = cv.imread('ggb.jpg',0)

# %%
print(img)
print(type(img))
# Out:
# [[ 73  68  62 ... 124 121 102]
#  [ 81  78  75 ... 126 122 114]
#  [ 84  80  76 ... 127 122 115]
#  ...
#  [ 42  34  30 ...  54  55  49]
#  [ 32  33  33 ...  37  43  40]
#  [ 55  40  31 ...  54  46  43]]
# <class 'numpy.ndarray'>

# %%
# imshow(imagename,image)
cv.imshow('image',img)
k = cv.waitKey(0)
if k == 27:         # wait for ESC key to exit
    cv.destroyAllWindows()
elif k == ord('s'): # wait for 's' key to save and exit
    cv.imwrite('messigray.png',img)
    cv.destroyAllWindows()

# %% [markdown]
# #### the python kernal does not close for imshow. -- issue --

# %%
# cv.imwrite('messigray.png',img)
# to write an image. 
# the first arg is the name of the file and the second argument is the image name

# %% [markdown]
# #### using matplotlib to display these are much more efficient way atleast for jupyter notebooks:

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %% [markdown]
# ### getting started with videos:

# %%
from IPython.display import clear_output
import time

# %%
cap = cv.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()
fig = plt.figure()
ax = fig.add_subplot(111)
for i in range(0,100):
    # Capture frame-by-frame
    ret, frame = cap.read()
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    # Our operations on the frame come here
    
    time.sleep(0.5)
    clear_output()
    
    gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    plt.imshow(gray, cmap = 'gray', interpolation = 'bicubic')
    plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
    plt.show()
    
    if cv.waitKey(1) == ord('q'):
        break
    
# When everything done, release the capture
cap.release()
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-61878ae5c715> in <module>
#      13         break
#      14     # Our operations on the frame come here
# ---> 15     time.sleep(0.5)
#      16     clear_output()
#      17     gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
#
# KeyboardInterrupt:

# %% [markdown]
# ### drawing on images

# %%
cv.rectangle(img,(384,0),(510,128),(0,255,0),3)
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img,'some text',(10,500), font, 4,(255,255,255),2,cv.LINE_AA)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %% [markdown]
# #### listening to mouse events in opencv - https://docs.opencv.org/master/db/d5b/tutorial_py_mouse_handling.html
